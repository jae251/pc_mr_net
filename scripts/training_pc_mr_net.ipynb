# %%
from datetime import datetime
print(datetime.now().time())
# Out:
# 13:38:27.440663

# %%
import torch

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
device = torch.cuda.current_device()
print(torch.cuda.get_device_capability(device))
print(torch.cuda.get_device_name(device))
# Out:
# True
# 1
# (3, 7)
# Tesla K80

# %%
# !nvidia-smi
# Out:
# Mon Apr  1 13:38:31 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.56       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    30W / 149W |     11MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import os
os.chdir("/content")
# !rm -r pc_mr_net
# !git clone --single-branch --branch colab_training https://github.com/jae251/pc_mr_net.git
# Out:
# Cloning into 'pc_mr_net'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 387 (delta 35), reused 41 (delta 19), pack-reused 328
# Receiving objects: 100% (387/387), 366.93 MiB | 43.42 MiB/s, done.
# Resolving deltas: 100% (202/202), done.

# %%
import shutil
shutil.copyfile("/content/drive/My Drive/pc_mr_net/data/dataset_one_car.zip", "/content/pc_mr_net/data/dataset_one_car.zip")
# Out:
# '/content/pc_mr_net/data/dataset_one_car.zip'

# %%
# !unzip /content/pc_mr_net/data/dataset_one_car.zip -d /content/pc_mr_net/data
# Out:
# Archive:  /content/pc_mr_net/data/dataset_one_car.zip
#    creating: /content/pc_mr_net/data/dataset_one_car/eval/
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10000.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10001.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10002.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10003.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10004.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10005.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10006.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10007.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10008.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10009.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10010.hdf5
#   inflating: /content/pc_mr_net/data/dataset_one_car/eval/10011.hdf5
# ...

# %%
# !ls "/content/pc_mr_net/data/dataset_one_car"
# Out:
# eval  train

# %%
import os
# os.environ["PYTHONPATH"] += ":/content/pc_mr_net"
os.environ["PYTHONPATH"] = "/env/python:/content/pc_mr_net"
print(os.environ["PYTHONPATH"])
# Out:
# /env/python:/content/pc_mr_net

# %%
# !pip install tensorboardX

# %%
os.chdir("/content/pc_mr_net/net_architectures/v07")
# !ls
# Out:
# evaluate.py  __init__.py  net_def.py  net_weights  train.py

# %%
# !python train.py
#!python evaluate.py
# Out:
# Loaded parameters from  /content/drive/My Drive/net_weights/0001.pt
# ==>>> total training batch number: 10000
# ==>>> total testing batch number: 2000
# EPOCH  0
# Saved model in  /content/drive/My Drive/net_weights/0002.pt
# EPOCH  1
# EPOCH  2
# EPOCH  3
# EPOCH  4
# EPOCH  5
# EPOCH  6
# EPOCH  7
# EPOCH  8
# EPOCH  9
# EPOCH  10
# Saved model in  /content/drive/My Drive/net_weights/0003.pt
# EPOCH  11
# EPOCH  12
# EPOCH  13
# EPOCH  14
# EPOCH  15
# EPOCH  16
# EPOCH  17
# 6520
